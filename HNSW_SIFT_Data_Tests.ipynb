# %%
# !pip install implicit
# !pip install faiss-cpu
# Out:
# Collecting implicit
#   Downloading implicit-0.7.1-cp310-cp310-manylinux2014_x86_64.whl (8.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 17.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from implicit) (1.23.5)
# Requirement already satisfied: scipy>=0.16 in /usr/local/lib/python3.10/dist-packages (from implicit) (1.10.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from implicit) (4.66.1)
# Installing collected packages: implicit
# Successfully installed implicit-0.7.1
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.7.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 34.2 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.7.4

# %%
import os
import time
import numpy as np
import pandas as pd

import faiss

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# ## Load Data

# %%
def ivecs_read(fname):
  a = np.fromfile(fname, dtype='int32')
  d = a[0]
  return a.reshape(-1, d + 1)[:, 1:].copy()

# %%
# download data from http://corpus-texmex.irisa.fr/ 
xq = ivecs_read('/content/drive/MyDrive/movie_lens/ml-100k/sift/sift_query.fvecs').view('float32')
xb = ivecs_read('/content/drive/MyDrive/movie_lens/ml-100k/sift/sift_base.fvecs').view('float32')
gt = ivecs_read('/content/drive/MyDrive/movie_lens/ml-100k/sift/sift_groundtruth.ivecs').view('float32')
xt = ivecs_read('/content/drive/MyDrive/movie_lens/ml-100k/sift/sift_learn.fvecs').view('float32')

# %%
nq, d = xq.shape

# %%
faiss.omp_set_num_threads(20)

# %% [markdown]
# ### HNSW Flat Index

# %%
index = faiss.IndexHNSWFlat(d, 32)
index.hnsw.efConstruction = 40
index.verbose = True
index.add(xb)

# %%
for efSearch in [16, 32, 64, 128, 256]:

  index.hnsw.efSearch = efSearch

  t0 = time.time()
  D, I = index.search(xq, 100)
  t1 = time.time()

  missing_rate = (I == -1).sum() / float(100 * nq)
  recall_at_1 = (I == gt[:, :1]).sum() / float(nq)
  print("%7.3f ms per query, R@1 %.4f" %(
        (t1 - t0) * 1000.0 / nq, recall_at_1))
# Out:
#   0.158 ms per query, R@1 0.9123
#   0.240 ms per query, R@1 0.9614
#   0.393 ms per query, R@1 0.9872
#   0.827 ms per query, R@1 0.9959
#   1.411 ms per query, R@1 0.9987

# %% [markdown]
# ### HNSW Hyperparameter Test

# %%
hnsw_results = []

m_vals_list = [8, 12, 16, 24, 32, 64]
efconstruction_vals_list = [4, 8, 12, 16, 24, 32]
efsearch_vals_list = [4, 8, 12, 16, 24, 32]


for M in m_vals_list:
  for efConstruction in efconstruction_vals_list:
    index = faiss.IndexHNSWFlat(d, M)
    index.hnsw.efConstruction = efConstruction
    index.verbose = True

    T0 = time.time()
    index.add(xb)
    T1 = time.time()

    print('Time taken for construction of HNSW index with M = {0} and efConstruciton = {1} is {2:.3f} s'.format(M, efConstruction, (T1-T0)))

    for efSearch in efsearch_vals_list:
      index.hnsw.efSearch = efSearch

      t0 = time.time()
      D, I = index.search(xq, 100)
      t1 = time.time()

      recall_at_1 = (I == gt[:, :1]).sum() / float(nq)
      print("For efSearch = %5d, Search Time = %7.3f ms per query, Recall@1 = %.4f" %(efSearch,
            (t1 - t0) * 1000.0 / nq, recall_at_1))

      hnsw_results.append(pd.DataFrame({'m' : [M], 'efSearch' : [efSearch], 'efConstruction' : [efConstruction], 'Search_Time_Per_Query' : [(t1 - t0) * 1000.0 / nq], 'Recall@1' : [recall_at_1]}))

    print('*'*100)
# Out:
# Time taken for construction of HNSW index with M = 8 and efConstruciton = 4 is 25.596 s
# For efSearch =     4, Search Time =   0.022 ms per query, Recall@1 = 0.1334
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.030 ms per query, Recall@1 = 0.1593
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.040 ms per query, Recall@1 = 0.1797
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.048 ms per query, Recall@1 = 0.1967
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.069 ms per query, Recall@1 = 0.2185
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.082 ms per query, Recall@1 = 0.2369
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 8 and efConstruciton = 8 is 50.938 s
# For efSearch =     4, Search Time =   0.055 ms per query, Recall@1 = 0.2370
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.076 ms per query, Recall@1 = 0.3282
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.067 ms per query, Recall@1 = 0.3865
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.072 ms per query, Recall@1 = 0.4336
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.098 ms per query, Recall@1 = 0.4993
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.130 ms per query, Recall@1 = 0.5497
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 8 and efConstruciton = 12 is 80.615 s
# For efSearch =     4, Search Time =   0.064 ms per query, Recall@1 = 0.3184
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.094 ms per query, Recall@1 = 0.4425
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.078 ms per query, Recall@1 = 0.5154
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.080 ms per query, Recall@1 = 0.5698
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.104 ms per query, Recall@1 = 0.6445
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.126 ms per query, Recall@1 = 0.6916
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 8 and efConstruciton = 16 is 70.081 s
# For efSearch =     4, Search Time =   0.031 ms per query, Recall@1 = 0.3109
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.046 ms per query, Recall@1 = 0.4321
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.066 ms per query, Recall@1 = 0.5076
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.073 ms per query, Recall@1 = 0.5570
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.091 ms per query, Recall@1 = 0.6311
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.117 ms per query, Recall@1 = 0.6794
# ****************************************************************************************************
# For efSearch =     4, Search Time =   0.039 ms per query, Recall@1 = 0.3699
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.049 ms per query, Recall@1 = 0.5105
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.065 ms per query, Recall@1 = 0.5943
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.131 ms per query, Recall@1 = 0.6500
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.176 ms per query, Recall@1 = 0.7186
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.172 ms per query, Recall@1 = 0.7660
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 8 and efConstruciton = 32 is 136.462 s
# For efSearch =     4, Search Time =   0.037 ms per query, Recall@1 = 0.4162
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.059 ms per query, Recall@1 = 0.5540
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.069 ms per query, Recall@1 = 0.6350
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.085 ms per query, Recall@1 = 0.6867
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.167 ms per query, Recall@1 = 0.7610
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.234 ms per query, Recall@1 = 0.8024
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 12 and efConstruciton = 4 is 28.361 s
# For efSearch =     4, Search Time =   0.049 ms per query, Recall@1 = 0.1533
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.037 ms per query, Recall@1 = 0.1848
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.050 ms per query, Recall@1 = 0.2088
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.058 ms per query, Recall@1 = 0.2245
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.078 ms per query, Recall@1 = 0.2516
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.091 ms per query, Recall@1 = 0.2720
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 12 and efConstruciton = 8 is 61.039 s
# For efSearch =     4, Search Time =   0.042 ms per query, Recall@1 = 0.2937
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.060 ms per query, Recall@1 = 0.3899
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.077 ms per query, Recall@1 = 0.4562
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.094 ms per query, Recall@1 = 0.5023
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.178 ms per query, Recall@1 = 0.5706
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.254 ms per query, Recall@1 = 0.6178
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 12 and efConstruciton = 12 is 92.412 s
# For efSearch =     4, Search Time =   0.047 ms per query, Recall@1 = 0.3975
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.072 ms per query, Recall@1 = 0.5265
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.088 ms per query, Recall@1 = 0.6072
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.105 ms per query, Recall@1 = 0.6619
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.205 ms per query, Recall@1 = 0.7276
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.281 ms per query, Recall@1 = 0.7720
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 12 and efConstruciton = 16 is 119.583 s
# For efSearch =     4, Search Time =   0.052 ms per query, Recall@1 = 0.4506
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.075 ms per query, Recall@1 = 0.5908
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.097 ms per query, Recall@1 = 0.6671
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.116 ms per query, Recall@1 = 0.7180
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.152 ms per query, Recall@1 = 0.7799
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.315 ms per query, Recall@1 = 0.8210
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 12 and efConstruciton = 24 is 114.648 s
# For efSearch =     4, Search Time =   0.041 ms per query, Recall@1 = 0.4223
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.060 ms per query, Recall@1 = 0.5643
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.077 ms per query, Recall@1 = 0.6435
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.094 ms per query, Recall@1 = 0.6989
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.118 ms per query, Recall@1 = 0.7676
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.142 ms per query, Recall@1 = 0.8107
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 12 and efConstruciton = 32 is 147.512 s
# For efSearch =     4, Search Time =   0.046 ms per query, Recall@1 = 0.4701
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.066 ms per query, Recall@1 = 0.6158
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.084 ms per query, Recall@1 = 0.6923
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.103 ms per query, Recall@1 = 0.7453
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.121 ms per query, Recall@1 = 0.8071
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.147 ms per query, Recall@1 = 0.8473
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 16 and efConstruciton = 4 is 28.895 s
# For efSearch =     4, Search Time =   0.028 ms per query, Recall@1 = 0.1659
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.040 ms per query, Recall@1 = 0.1978
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.051 ms per query, Recall@1 = 0.2189
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.061 ms per query, Recall@1 = 0.2349
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.082 ms per query, Recall@1 = 0.2624
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.177 ms per query, Recall@1 = 0.2871
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 16 and efConstruciton = 8 is 62.440 s
# For efSearch =     4, Search Time =   0.042 ms per query, Recall@1 = 0.3229
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.066 ms per query, Recall@1 = 0.4240
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.083 ms per query, Recall@1 = 0.4880
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.095 ms per query, Recall@1 = 0.5379
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.125 ms per query, Recall@1 = 0.6047
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.154 ms per query, Recall@1 = 0.6564
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 16 and efConstruciton = 12 is 96.038 s
# For efSearch =     4, Search Time =   0.056 ms per query, Recall@1 = 0.4334
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.077 ms per query, Recall@1 = 0.5639
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.099 ms per query, Recall@1 = 0.6409
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.142 ms per query, Recall@1 = 0.6906
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.258 ms per query, Recall@1 = 0.7559
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.213 ms per query, Recall@1 = 0.7991
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 16 and efConstruciton = 16 is 127.698 s
# For efSearch =     4, Search Time =   0.071 ms per query, Recall@1 = 0.4945
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.082 ms per query, Recall@1 = 0.6363
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.100 ms per query, Recall@1 = 0.7123
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.120 ms per query, Recall@1 = 0.7561
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.153 ms per query, Recall@1 = 0.8179
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.182 ms per query, Recall@1 = 0.8552
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 16 and efConstruciton = 24 is 191.806 s
# For efSearch =     4, Search Time =   0.063 ms per query, Recall@1 = 0.5480
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.091 ms per query, Recall@1 = 0.6915
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.111 ms per query, Recall@1 = 0.7654
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.131 ms per query, Recall@1 = 0.8132
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.165 ms per query, Recall@1 = 0.8699
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.199 ms per query, Recall@1 = 0.9004
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 16 and efConstruciton = 32 is 156.435 s
# For efSearch =     4, Search Time =   0.050 ms per query, Recall@1 = 0.4936
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.130 ms per query, Recall@1 = 0.6419
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.160 ms per query, Recall@1 = 0.7222
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.158 ms per query, Recall@1 = 0.7733
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.139 ms per query, Recall@1 = 0.8319
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.162 ms per query, Recall@1 = 0.8687
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 24 and efConstruciton = 4 is 31.753 s
# For efSearch =     4, Search Time =   0.033 ms per query, Recall@1 = 0.1709
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.049 ms per query, Recall@1 = 0.2053
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.059 ms per query, Recall@1 = 0.2299
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.068 ms per query, Recall@1 = 0.2487
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.104 ms per query, Recall@1 = 0.2790
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.206 ms per query, Recall@1 = 0.3022
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 24 and efConstruciton = 8 is 67.453 s
# For efSearch =     4, Search Time =   0.054 ms per query, Recall@1 = 0.3538
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.129 ms per query, Recall@1 = 0.4584
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.172 ms per query, Recall@1 = 0.5264
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.163 ms per query, Recall@1 = 0.5794
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.145 ms per query, Recall@1 = 0.6486
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.173 ms per query, Recall@1 = 0.6937
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 24 and efConstruciton = 12 is 102.376 s
# For efSearch =     4, Search Time =   0.064 ms per query, Recall@1 = 0.4787
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.093 ms per query, Recall@1 = 0.6094
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.171 ms per query, Recall@1 = 0.6811
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.233 ms per query, Recall@1 = 0.7315
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.193 ms per query, Recall@1 = 0.7921
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.200 ms per query, Recall@1 = 0.8290
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 24 and efConstruciton = 16 is 137.796 s
# For efSearch =     4, Search Time =   0.074 ms per query, Recall@1 = 0.5435
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.101 ms per query, Recall@1 = 0.6799
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.125 ms per query, Recall@1 = 0.7501
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.154 ms per query, Recall@1 = 0.7967
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.189 ms per query, Recall@1 = 0.8525
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.227 ms per query, Recall@1 = 0.8849
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 24 and efConstruciton = 24 is 211.659 s
# For efSearch =     4, Search Time =   0.134 ms per query, Recall@1 = 0.6145
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.205 ms per query, Recall@1 = 0.7491
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.156 ms per query, Recall@1 = 0.8148
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.159 ms per query, Recall@1 = 0.8570
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.203 ms per query, Recall@1 = 0.9049
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.246 ms per query, Recall@1 = 0.9276
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 24 and efConstruciton = 32 is 280.386 s
# For efSearch =     4, Search Time =   0.079 ms per query, Recall@1 = 0.6448
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.115 ms per query, Recall@1 = 0.7782
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.138 ms per query, Recall@1 = 0.8416
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.215 ms per query, Recall@1 = 0.8761
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.339 ms per query, Recall@1 = 0.9209
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.252 ms per query, Recall@1 = 0.9418
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 32 and efConstruciton = 4 is 33.403 s
# For efSearch =     4, Search Time =   0.038 ms per query, Recall@1 = 0.1885
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.049 ms per query, Recall@1 = 0.2224
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.063 ms per query, Recall@1 = 0.2456
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.127 ms per query, Recall@1 = 0.2649
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.169 ms per query, Recall@1 = 0.2934
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.178 ms per query, Recall@1 = 0.3195
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 32 and efConstruciton = 8 is 71.996 s
# For efSearch =     4, Search Time =   0.056 ms per query, Recall@1 = 0.3706
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.083 ms per query, Recall@1 = 0.4810
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.107 ms per query, Recall@1 = 0.5478
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.122 ms per query, Recall@1 = 0.5945
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.156 ms per query, Recall@1 = 0.6676
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.183 ms per query, Recall@1 = 0.7129
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 32 and efConstruciton = 12 is 108.929 s
# For efSearch =     4, Search Time =   0.071 ms per query, Recall@1 = 0.4945
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.102 ms per query, Recall@1 = 0.6254
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.131 ms per query, Recall@1 = 0.6998
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.229 ms per query, Recall@1 = 0.7489
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.277 ms per query, Recall@1 = 0.8090
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.219 ms per query, Recall@1 = 0.8444
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 32 and efConstruciton = 16 is 144.826 s
# For efSearch =     4, Search Time =   0.076 ms per query, Recall@1 = 0.5747
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.110 ms per query, Recall@1 = 0.7044
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.213 ms per query, Recall@1 = 0.7705
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.261 ms per query, Recall@1 = 0.8146
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.191 ms per query, Recall@1 = 0.8646
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.234 ms per query, Recall@1 = 0.8973
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 32 and efConstruciton = 24 is 228.301 s
# For efSearch =     4, Search Time =   0.094 ms per query, Recall@1 = 0.6537
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.167 ms per query, Recall@1 = 0.7802
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.277 ms per query, Recall@1 = 0.8388
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.203 ms per query, Recall@1 = 0.8768
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.229 ms per query, Recall@1 = 0.9181
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.288 ms per query, Recall@1 = 0.9390
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 32 and efConstruciton = 32 is 300.336 s
# For efSearch =     4, Search Time =   0.165 ms per query, Recall@1 = 0.6858
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.130 ms per query, Recall@1 = 0.8083
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.161 ms per query, Recall@1 = 0.8661
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.190 ms per query, Recall@1 = 0.9048
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.243 ms per query, Recall@1 = 0.9385
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.314 ms per query, Recall@1 = 0.9557
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 64 and efConstruciton = 4 is 39.293 s
# For efSearch =     4, Search Time =   0.047 ms per query, Recall@1 = 0.1998
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.060 ms per query, Recall@1 = 0.2395
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.072 ms per query, Recall@1 = 0.2643
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.092 ms per query, Recall@1 = 0.2852
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.178 ms per query, Recall@1 = 0.3204
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.218 ms per query, Recall@1 = 0.3452
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 64 and efConstruciton = 8 is 83.409 s
# For efSearch =     4, Search Time =   0.115 ms per query, Recall@1 = 0.3979
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.106 ms per query, Recall@1 = 0.5105
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.120 ms per query, Recall@1 = 0.5758
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.147 ms per query, Recall@1 = 0.6246
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.179 ms per query, Recall@1 = 0.6892
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.207 ms per query, Recall@1 = 0.7323
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 64 and efConstruciton = 12 is 131.311 s
# For efSearch =     4, Search Time =   0.109 ms per query, Recall@1 = 0.5411
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.123 ms per query, Recall@1 = 0.6631
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.149 ms per query, Recall@1 = 0.7334
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.175 ms per query, Recall@1 = 0.7766
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.227 ms per query, Recall@1 = 0.8316
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.250 ms per query, Recall@1 = 0.8650
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 64 and efConstruciton = 16 is 175.781 s
# For efSearch =     4, Search Time =   0.106 ms per query, Recall@1 = 0.6162
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.141 ms per query, Recall@1 = 0.7358
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.172 ms per query, Recall@1 = 0.7991
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.198 ms per query, Recall@1 = 0.8378
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.383 ms per query, Recall@1 = 0.8893
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.315 ms per query, Recall@1 = 0.9133
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 64 and efConstruciton = 24 is 267.896 s
# For efSearch =     4, Search Time =   0.119 ms per query, Recall@1 = 0.7031
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.160 ms per query, Recall@1 = 0.8186
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.207 ms per query, Recall@1 = 0.8757
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.392 ms per query, Recall@1 = 0.9032
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.279 ms per query, Recall@1 = 0.9369
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.340 ms per query, Recall@1 = 0.9551
# ****************************************************************************************************
# Time taken for construction of HNSW index with M = 64 and efConstruciton = 32 is 374.067 s
# For efSearch =     4, Search Time =   0.136 ms per query, Recall@1 = 0.7522
# ****************************************************************************************************
# For efSearch =     8, Search Time =   0.177 ms per query, Recall@1 = 0.8558
# ****************************************************************************************************
# For efSearch =    12, Search Time =   0.218 ms per query, Recall@1 = 0.9056
# ****************************************************************************************************
# For efSearch =    16, Search Time =   0.396 ms per query, Recall@1 = 0.9309
# ****************************************************************************************************
# For efSearch =    24, Search Time =   0.365 ms per query, Recall@1 = 0.9599
# ****************************************************************************************************
# For efSearch =    32, Search Time =   0.390 ms per query, Recall@1 = 0.9718
# ****************************************************************************************************

# %%
hnsw_results_df = pd.concat(hnsw_results, axis = 0)
hnsw_results_df
# Out:
#      m  efSearch  efConstruction  Search_Time_Per_Query  Recall@1
# 0    8         4               4               0.022081    0.1334
# 0    8         8               4               0.029712    0.1593
# 0    8        12               4               0.040308    0.1797
# 0    8        16               4               0.047703    0.1967
# 0    8        24               4               0.068829    0.2185
# ..  ..       ...             ...                    ...       ...
# 0   64         8              32               0.177414    0.8558
# 0   64        12              32               0.218144    0.9056
# 0   64        16              32               0.396230    0.9309
# 0   64        24              32               0.364841    0.9599
# 0   64        32              32               0.389830    0.9718
#
# [216 rows x 5 columns]

# %%
# !mkdir -p "/content/drive/My Drive/Temp Results"

# %%
hnsw_results_df.to_csv('/content/drive/My Drive/Temp Results/hnsw_sift1m_results.csv')

# %%
exact_index = faiss.index_factory(d, "Flat")
exact_index.add(xb)

# %%
t0 = time.time()
D, I = exact_index.search(xq, 100)
t1 = time.time()

recall_at_1 = (I == gt[:, :1]).sum() / float(nq)
print("Search Time = %7.3f ms per query, Recall@1 = %.4f" %(
            (t1 - t0) * 1000.0 / nq, recall_at_1))
# Out:
# Search Time =   7.965 ms per query, Recall@1 = 1.0000

# %% [markdown]
# ### HNSW with Quantizer

# %%
index = faiss.IndexHNSWSQ(d, faiss.ScalarQuantizer.QT_8bit, 16)

# %%
index.train(xt)
index.hnsw.efConstruction = 40
index.hnsw.efSearch = 32

index.verbose = True
index.add(xb)

# %%
for efSearch in 16, 32, 64, 128, 256:

  index.hnsw.efSearch = efSearch
  t0 = time.time()
  D, I = index.search(xq, 100)
  t1 = time.time()

  missing_rate = (I == -1).sum() / float(100 * nq)
  recall_at_1 = (I == gt[:, :1]).sum() / float(nq)
  print("%7.3f ms per query, R@1 %.4f" %(
          (t1 - t0) * 1000.0 / nq, recall_at_1))
# Out:
#   0.160 ms per query, R@1 0.8026
#   0.241 ms per query, R@1 0.8934
#   0.224 ms per query, R@1 0.9492
#   0.346 ms per query, R@1 0.9796
#   0.782 ms per query, R@1 0.9921

# %% [markdown]
# ### IVF with HNSW Quantizer

# %%
quantizer = faiss.IndexHNSWFlat(d, 32)
index = faiss.IndexIVFFlat(quantizer, d, 16384)
index.cp.min_points_per_centroid = 5
index.quantizer_trains_alone = 2

# %%
index.verbose = True
index.train(xt)
index.add(xb)

# %%
quantizer.hnsw.efSearch = 64
for nprobe in 1, 4, 16, 64, 256:
  index.nprobe = nprobe

  t0 = time.time()
  D, I = index.search(xq, 100)
  t1 = time.time()

  missing_rate = (I == -1).sum() / float(100 * nq)
  recall_at_1 = (I == gt[:, :1]).sum() / float(nq)
  print("%7.3f ms per query, R@1 %.4f" %(
          (t1 - t0) * 1000.0 / nq, recall_at_1))
# Out:
#   0.088 ms per query, R@1 0.4094
#   0.109 ms per query, R@1 0.6323
#   0.177 ms per query, R@1 0.8299
#   0.395 ms per query, R@1 0.9549
#   1.390 ms per query, R@1 0.9927
